# %%
import socket
import os
import json
import time
import numpy as np
from sklearn.neural_network import MLPClassifier

# Constantes de configuração
CLIENT_HOST = 'localhost'
CLIENT_PORT_SEND = 5104  # Porta para enviar modelo global para clientes
CLIENT_PORT_RECV = 5105  # Porta para receber modelo local dos clientes

MASTER_HOST = 'localhost'
MASTER_PORT_SEND = 6000  # Envia modelo intermediário para a nuvem
MASTER_PORT_RECV = 6001  # Recebe modelo global da nuvem

SERVER_ID = 3   # Identificador do servidor (para simulação com múltiplos servidores)
NUM_CLIENTS = 3 # Quantidade de clientes esperados

def receive_client_parameters(conn):
    data = b""
    while True:
        packet = conn.recv(CLIENT_PORT_RECV)
        if not packet:
            break
        data += packet

    decoded = json.loads(data.decode('utf-8'))
    coef = [np.array(layer) for layer in decoded['coef']]
    intercept = [np.array(b) for b in decoded['intercept']]
    data_size = int(decoded['data_size'])

    return coef, intercept, data_size

global_coef = None
global_intercept = None

print(f"\n[Servidor Hospital {SERVER_ID}] Inicializado...")

print(f"\n[Servidor Hospital {SERVER_ID}] Aguardando modelo global inicial da nuvem...")

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_RECV))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)

    try:
        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
        global_params = decoded.get("params", {})
        NUM_ROUNDS = np.array(decoded['num_rounds']) 

        # Cria o modelo com os mesmos hiperparâmetros do master
        global_model = MLPClassifier(**global_params)

        # Atribui os pesos recebidos
        global_model.coefs_ = [np.array(layer) for layer in decoded['coef']]
        global_model.intercepts_ = [np.array(b) for b in decoded['intercept']]
        
        print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial recebido com sucesso!")
    except Exception as e:
        print(f"[Servidor Hospital {SERVER_ID}] Erro ao receber modelo inicial: {e}")
    finally:
        s.close()

print(f"\n[Servidor Hospital {SERVER_ID}] Conectando aos clientes...")    
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
    s.listen(NUM_CLIENTS)

    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Conectado ao cliente {i+1}!")
            print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global inicial para o cliente {i+1}...")
            model_data = {
                "coef": [layer.tolist() for layer in global_coef],
                "intercept": [b.tolist() for b in global_intercept],
                "num_rounds" : int(NUM_ROUNDS),
                "params": {
                    "hidden_layer_sizes": global_model.hidden_layer_sizes,
                    "activation": global_model.activation,
                    "solver": global_model.solver,
                    "learning_rate_init": global_model.learning_rate_init,
                    "alpha": global_model.alpha,
                    "max_iter": global_model.max_iter,
                    "warm_start": global_model.warm_start,
                    "n_iter_no_change": global_model.n_iter_no_change,
                    "random_state": global_model.random_state
                }
            }
            data = json.dumps(model_data).encode('utf-8') 
            conn.sendall(data)
            print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial enviado para o cliente {i+1} com sucesso!")

for round_num in range(1, NUM_ROUNDS + 1):
    print(f"\n[Servidor Hospital {SERVER_ID}] Iniciando rodada {round_num} de aprendizado federado")

    client_weights = []
    client_sizes = []

    # Receber modelo local dos clientes
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
        s.listen(NUM_CLIENTS)
        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                client_coef, client_intercept, data_size = receive_client_parameters(conn)

                if not (isinstance(client_coef, list) and all(isinstance(layer, np.ndarray) for layer in client_coef) and
                    isinstance(client_intercept, list) and all(isinstance(b, np.ndarray) for b in client_intercept) and
                    isinstance(data_size, int)):
                    raise ValueError("Dados recebidos do cliente estão em formato incorreto.")

                client_weights.append((client_coef, client_intercept))
                client_sizes.append(data_size)

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

    # Inicializa os acumuladores se for a primeira rodada
    if global_coef is None:
        # Inicializa uma lista de arrays, um para cada camada
        global_coef = [np.zeros_like(layer) for layer in hospital_weights[0][0]]
        global_intercept = [np.zeros_like(bias) for bias in hospital_weights[0][1]]
    else:
        # Zera os valores das camadas
        for i in range(len(global_coef)):
            global_coef[i].fill(0)
            global_intercept[i].fill(0)

    total_data_size = sum(client_sizes)
    if total_data_size == 0:
        raise ValueError("Tamanho total dos dados dos clientes é zero.")

    # Realização do FedAvg(Agregação por média)
    # Coef e Intercept são os parâmetros utilizados pelo modelo
    # - Coef(Coeficiente): Representa os pesos atribuídos a cada atributo (feature) do modelo. É um vetor ou matriz (dependendo da tarefa) que determina quanto cada variável influencia a predição.
    # - Intercept(Intercepto): É o termo de bias, o valor que o modelo usa quando todas as entradas são zero. Serve para ajustar o ponto de corte (threshold) da função de decisão.
    print(f"[Servidor Hospital {SERVER_ID}] Realizando FedAvg do modelo intermediário...")
    for i in range(NUM_CLIENTS):
        weight = client_sizes[i] / total_data_size
        local_coef, local_intercept = client_weights[i]

        for j in range(len(global_coef)):
            global_coef[j] += local_coef[j] * weight
            global_intercept[j] += local_intercept[j] * weight

    # Atualizar modelo global
    global_model.coefs_ = global_coef
    global_model.intercepts_ = global_intercept
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário atualizado na rodada {round_num}!")

    # Enviar modelo intermediário para a nuvem
    hospital_model = {
        "coef": [layer.tolist() for layer in global_coef],
        "intercept": [b.tolist() for b in global_intercept],
        "data_size": total_data_size
    }

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo intermediário para a nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_SEND))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)
        s.sendall(json.dumps(hospital_model).encode('utf-8'))
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário enviado para a nuvem com sucesso!")

    # Receber modelo global da nuvem
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando modelo global da nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_RECV))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)

        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
    print(f"[Servidor Hospital {SERVER_ID}] Modelo global recebido da nuvem com sucesso!")

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global aos clientes...")    
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
        s.listen(NUM_CLIENTS)

        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                model_data = {
                    "coef": [layer.tolist() for layer in global_coef],
                    "intercept": [b.tolist() for b in global_intercept],
                }
                data = json.dumps(model_data).encode('utf-8') 
                print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global para o cliente {i+1}...")
                conn.sendall(data)
                print(f"[Servidor Hospital {SERVER_ID}] Modelo global enviado para o cliente {i+1} com sucesso!")

print(f"\n[Servidor Hospital {SERVER_ID}] Todas as rodadas de treinamento federado foram concluídas!")

# Receber f1 dos clientes
f1_all_clients = {}  # dicionário para armazenar F1 por cliente
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                received = json.loads(received_data.decode('utf-8'))
                client_id = received["id"]
                f1_all_clients[client_id] = received["f1"]

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Enviar f1 dos clientes para o master
print(f"[Servidor Hospital {SERVER_ID}] Enviando f1 dos clientes para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    data_to_send = {
        "id": SERVER_ID,
        "f1": f1_all_clients
    }
    s.sendall(json.dumps(data_to_send).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")

aggregated_metrics = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Receber métricas de desempenho do modelo local dos clientes
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                metrics = json.loads(received_data.decode('utf-8'))
                aggregated_metrics['accuracy'].append(metrics['accuracy'])
                aggregated_metrics['precision'].append(metrics['precision'])
                aggregated_metrics['recall'].append(metrics['recall'])
                aggregated_metrics['f1_score'].append(metrics['f1_score'])

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Média intermediária
avg_metrics = {k: np.mean(v) for k, v in aggregated_metrics.items()}

# Enviar ao mestre
print(f"[Servidor Hospital {SERVER_ID}] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    s.sendall(json.dumps(avg_metrics).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")
# Out:
# [Servidor Hospital 3] Inicializado...
#
# [Servidor Hospital 3] Aguardando modelo global inicial da nuvem...
# [Servidor Hospital 3] Modelo global inicial recebido com sucesso!
#
# [Servidor Hospital 3] Conectando aos clientes...
# [Servidor Hospital 3] Conectado ao cliente 1!
# [Servidor Hospital 3] Enviando modelo global inicial para o cliente 1...
# [Servidor Hospital 3] Modelo global inicial enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Conectado ao cliente 2!
# [Servidor Hospital 3] Enviando modelo global inicial para o cliente 2...
# [Servidor Hospital 3] Modelo global inicial enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Conectado ao cliente 3!
# [Servidor Hospital 3] Enviando modelo global inicial para o cliente 3...
# [Servidor Hospital 3] Modelo global inicial enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 1 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54810)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54774)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 65213)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 1!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54856)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54858)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 64205)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 2 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 64206)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54859)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54857)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 2!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 64246)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 64248)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 64254)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 3 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 64255)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 64247)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 64251)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 3!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 55665)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 55667)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 55669)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 4 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 55673)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 55666)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 55668)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 4!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58328)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58331)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58339)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 5 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58340)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58333)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58336)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 5!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58363)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58365)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58368)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 6 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58369)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58370)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58364)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 6!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61346)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61347)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61361)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 7 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61375)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61355)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61356)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 7!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61400)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61403)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 53533)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 8 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 53537)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 53539)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61401)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 8!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 53561)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 53562)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 53570)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 9 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 53571)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 53563)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 53566)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 9!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 53595)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 53597)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 53599)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 10 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 53604)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 53596)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 53598)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 10!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 62194)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 62203)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 62205)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 11 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 62206)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 62197)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 62204)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 11!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 62243)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 62252)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 62368)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 12 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 62369)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 62244)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 62367)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 12!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52181)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52183)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52184)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 13 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52185)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52189)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52182)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 13!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52219)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52222)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52226)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 14 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52227)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52224)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52225)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 14!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58053)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58055)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58056)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 15 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58057)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58059)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58054)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 15!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58086)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58087)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58090)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 16 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54535)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58088)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58089)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 16!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54080)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54085)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54087)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 17 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54081)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54089)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54086)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 17!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54134)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54135)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54138)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 18 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54140)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54136)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54137)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 18!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 50595)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 50597)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 50598)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 19 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61150)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 50596)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 50599)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 19!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61175)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61180)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61182)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 20 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61183)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61179)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61181)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 20!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58325)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58328)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58330)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 21 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58331)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58327)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58329)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 21!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58377)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58380)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58381)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 22 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58383)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 58379)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 58382)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 22!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 58411)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61820)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61822)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 23 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61823)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61819)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61821)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 23!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61864)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61866)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61868)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 24 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 61869)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 61865)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 61867)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 24!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51369)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51371)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51372)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 25 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51373)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51375)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51370)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 25!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51402)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51403)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51459)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 26 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51460)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51404)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51405)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 26!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51490)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51492)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51493)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 27 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 50419)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 50421)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51491)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 27!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 50464)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 50465)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 50468)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 28 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 50469)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 50466)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 50467)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 28!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 50549)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51873)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51874)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 29 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51875)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51877)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51872)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 29!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51904)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51905)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51908)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 30 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51909)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51906)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51907)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# ...
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51765)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 42 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51766)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51768)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51763)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 42!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51795)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51796)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51799)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 43 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51800)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 51797)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 51798)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 43!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 51828)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 65200)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 65206)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 44 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 65208)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 65210)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 65199)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 44!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 65236)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 65237)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 65240)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 45 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 65241)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 65238)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 65239)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 45!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 63107)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 63109)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 63110)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 46 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 63113)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 63108)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 63111)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 46!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 63152)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 63154)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 63156)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 47 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 63157)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 63153)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 63155)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 47!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 60038)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 60071)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 60074)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 48 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 60075)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 60073)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 60072)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 48!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 60124)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 60126)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 60127)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 49 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 60128)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 60130)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 60125)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 49!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52308)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52309)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52312)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Iniciando rodada 50 de aprendizado federado
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52313)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52310)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52311)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 3] Modelo intermediário atualizado na rodada 50!
# [Servidor Hospital 3] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 3] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando modelo global da nuvem...
# [Servidor Hospital 3] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 3] Enviando modelo global aos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52325)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 1...
# [Servidor Hospital 3] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52328)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 2...
# [Servidor Hospital 3] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52329)!
# [Servidor Hospital 3] Enviando modelo global para o cliente 3...
# [Servidor Hospital 3] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 3] Todas as rodadas de treinamento federado foram concluídas!
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 52336)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 52337)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 52338)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Enviando f1 dos clientes para a nuvem...
# [Servidor Hospital 3] Parâmetros enviados para a nuvem com sucesso!
# [Servidor Hospital 3] Aguardando conexão dos clientes...
# [Servidor Hospital 3] Cliente 1 conectado: ('127.0.0.1', 54277)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 3] Cliente 2 conectado: ('127.0.0.1', 54278)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 3] Cliente 3 conectado: ('127.0.0.1', 54279)!
# [Servidor Hospital 3] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 3] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...
# [Servidor Hospital 3] Parâmetros enviados para a nuvem com sucesso!
