# %%
import socket
import os
import json
import time
import numpy as np
from sklearn.neural_network import MLPClassifier

# Constantes de configuração
CLIENT_HOST = 'localhost'
CLIENT_PORT_SEND = 5100  # Porta para enviar modelo global para clientes
CLIENT_PORT_RECV = 5101  # Porta para receber modelo local dos clientes

MASTER_HOST = 'localhost'
MASTER_PORT_SEND = 6000  # Envia modelo intermediário para a nuvem
MASTER_PORT_RECV = 6001  # Recebe modelo global da nuvem

SERVER_ID = 1   # Identificador do servidor (para simulação com múltiplos servidores)
NUM_CLIENTS = 3 # Quantidade de clientes esperados

def receive_client_parameters(conn):
    data = b""
    while True:
        packet = conn.recv(CLIENT_PORT_RECV)
        if not packet:
            break
        data += packet

    decoded = json.loads(data.decode('utf-8'))
    coef = [np.array(layer) for layer in decoded['coef']]
    intercept = [np.array(b) for b in decoded['intercept']]
    data_size = int(decoded['data_size'])

    return coef, intercept, data_size

global_coef = None
global_intercept = None

print(f"\n[Servidor Hospital {SERVER_ID}] Inicializado...")

print(f"\n[Servidor Hospital {SERVER_ID}] Aguardando modelo global inicial da nuvem...")

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_RECV))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)

    try:
        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
        global_params = decoded.get("params", {})
        NUM_ROUNDS = np.array(decoded['num_rounds']) 

        # Cria o modelo com os mesmos hiperparâmetros do master
        global_model = MLPClassifier(**global_params)

        # Atribui os pesos recebidos
        global_model.coefs_ = [np.array(layer) for layer in decoded['coef']]
        global_model.intercepts_ = [np.array(b) for b in decoded['intercept']]
        
        print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial recebido com sucesso!")
    except Exception as e:
        print(f"[Servidor Hospital {SERVER_ID}] Erro ao receber modelo inicial: {e}")
    finally:
        s.close()

print(f"\n[Servidor Hospital {SERVER_ID}] Conectando aos clientes...")    
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
    s.listen(NUM_CLIENTS)

    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Conectado ao cliente {i+1}!")
            print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global inicial para o cliente {i+1}...")
            model_data = {
                "coef": [layer.tolist() for layer in global_coef],
                "intercept": [b.tolist() for b in global_intercept],
                "num_rounds" : int(NUM_ROUNDS),
                "params": {
                    "hidden_layer_sizes": global_model.hidden_layer_sizes,
                    "activation": global_model.activation,
                    "solver": global_model.solver,
                    "learning_rate_init": global_model.learning_rate_init,
                    "alpha": global_model.alpha,
                    "max_iter": global_model.max_iter,
                    "warm_start": global_model.warm_start,
                    "n_iter_no_change": global_model.n_iter_no_change,
                    "random_state": global_model.random_state
                }
            }
            data = json.dumps(model_data).encode('utf-8') 
            conn.sendall(data)
            print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial enviado para o cliente {i+1} com sucesso!")

for round_num in range(1, NUM_ROUNDS + 1):
    print(f"\n[Servidor Hospital {SERVER_ID}] Iniciando rodada {round_num} de aprendizado federado")

    client_weights = []
    client_sizes = []

    # Receber modelo local dos clientes
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
        s.listen(NUM_CLIENTS)
        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                client_coef, client_intercept, data_size = receive_client_parameters(conn)

                if not (isinstance(client_coef, list) and all(isinstance(layer, np.ndarray) for layer in client_coef) and
                    isinstance(client_intercept, list) and all(isinstance(b, np.ndarray) for b in client_intercept) and
                    isinstance(data_size, int)):
                    raise ValueError("Dados recebidos do cliente estão em formato incorreto.")

                client_weights.append((client_coef, client_intercept))
                client_sizes.append(data_size)

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

    # Inicializa os acumuladores se for a primeira rodada
    if global_coef is None:
        # Inicializa uma lista de arrays, um para cada camada
        global_coef = [np.zeros_like(layer) for layer in hospital_weights[0][0]]
        global_intercept = [np.zeros_like(bias) for bias in hospital_weights[0][1]]
    else:
        # Zera os valores das camadas
        for i in range(len(global_coef)):
            global_coef[i].fill(0)
            global_intercept[i].fill(0)

    total_data_size = sum(client_sizes)
    if total_data_size == 0:
        raise ValueError("Tamanho total dos dados dos clientes é zero.")

    # Realização do FedAvg(Agregação por média)
    # Coef e Intercept são os parâmetros utilizados pelo modelo
    # - Coef(Coeficiente): Representa os pesos atribuídos a cada atributo (feature) do modelo. É um vetor ou matriz (dependendo da tarefa) que determina quanto cada variável influencia a predição.
    # - Intercept(Intercepto): É o termo de bias, o valor que o modelo usa quando todas as entradas são zero. Serve para ajustar o ponto de corte (threshold) da função de decisão.
    print(f"[Servidor Hospital {SERVER_ID}] Realizando FedAvg do modelo intermediário...")
    for i in range(NUM_CLIENTS):
        weight = client_sizes[i] / total_data_size
        local_coef, local_intercept = client_weights[i]

        for j in range(len(global_coef)):
            global_coef[j] += local_coef[j] * weight
            global_intercept[j] += local_intercept[j] * weight

    # Atualizar modelo global
    global_model.coefs_ = global_coef
    global_model.intercepts_ = global_intercept
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário atualizado na rodada {round_num}!")

    # Enviar modelo intermediário para a nuvem
    hospital_model = {
        "coef": [layer.tolist() for layer in global_coef],
        "intercept": [b.tolist() for b in global_intercept],
        "data_size": total_data_size
    }

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo intermediário para a nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_SEND))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)
        s.sendall(json.dumps(hospital_model).encode('utf-8'))
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário enviado para a nuvem com sucesso!")

    # Receber modelo global da nuvem
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando modelo global da nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_RECV))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)

        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
    print(f"[Servidor Hospital {SERVER_ID}] Modelo global recebido da nuvem com sucesso!")

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global aos clientes...")    
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
        s.listen(NUM_CLIENTS)

        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                model_data = {
                    "coef": [layer.tolist() for layer in global_coef],
                    "intercept": [b.tolist() for b in global_intercept],
                }
                data = json.dumps(model_data).encode('utf-8') 
                print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global para o cliente {i+1}...")
                conn.sendall(data)
                print(f"[Servidor Hospital {SERVER_ID}] Modelo global enviado para o cliente {i+1} com sucesso!")

print(f"\n[Servidor Hospital {SERVER_ID}] Todas as rodadas de treinamento federado foram concluídas!")

# Receber f1 dos clientes
f1_all_clients = {}  # dicionário para armazenar F1 por cliente
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                received = json.loads(received_data.decode('utf-8'))
                client_id = received["id"]
                f1_all_clients[client_id] = received["f1"]

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Enviar f1 dos clientes para o master
print(f"[Servidor Hospital {SERVER_ID}] Enviando f1 dos clientes para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    data_to_send = {
        "id": SERVER_ID,
        "f1": f1_all_clients
    }
    s.sendall(json.dumps(data_to_send).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")

aggregated_metrics = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Receber métricas de desempenho do modelo local dos clientes
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                metrics = json.loads(received_data.decode('utf-8'))
                aggregated_metrics['accuracy'].append(metrics['accuracy'])
                aggregated_metrics['precision'].append(metrics['precision'])
                aggregated_metrics['recall'].append(metrics['recall'])
                aggregated_metrics['f1_score'].append(metrics['f1_score'])

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Média intermediária
avg_metrics = {k: np.mean(v) for k, v in aggregated_metrics.items()}

# Enviar ao mestre
print(f"[Servidor Hospital {SERVER_ID}] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    s.sendall(json.dumps(avg_metrics).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")
# Out:
# [Servidor Hospital 1] Inicializado...
#
# [Servidor Hospital 1] Aguardando modelo global inicial da nuvem...
# [Servidor Hospital 1] Modelo global inicial recebido com sucesso!
#
# [Servidor Hospital 1] Conectando aos clientes...
# [Servidor Hospital 1] Conectado ao cliente 1!
# [Servidor Hospital 1] Enviando modelo global inicial para o cliente 1...
# [Servidor Hospital 1] Modelo global inicial enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Conectado ao cliente 2!
# [Servidor Hospital 1] Enviando modelo global inicial para o cliente 2...
# [Servidor Hospital 1] Modelo global inicial enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Conectado ao cliente 3!
# [Servidor Hospital 1] Enviando modelo global inicial para o cliente 3...
# [Servidor Hospital 1] Modelo global inicial enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 1 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 53437)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 56301)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 60348)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 1!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 64208)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 64210)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 64211)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 2 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 64213)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 64215)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 64209)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 2!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 64249)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 64250)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 64258)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 3 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 64260)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 64252)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 64253)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 3!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 55670)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 55671)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 55672)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 4 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 55675)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 55677)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 55680)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 4!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58329)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58330)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58334)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 5 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58337)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58332)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58335)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 5!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58361)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58366)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58367)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 6 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58373)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58362)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58376)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 6!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61348)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61349)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61350)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 7 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61351)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61353)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61357)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 7!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61393)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61394)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61397)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 8 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61398)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61395)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61396)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 8!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 53551)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 53557)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 53558)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 9 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 53559)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 53564)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 53555)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 9!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 53585)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 53589)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 53591)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 10 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 53593)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 53590)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 53592)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 10!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 62186)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 62192)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 62193)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 11 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 62195)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 62198)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 62190)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 11!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 62235)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 62237)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 62238)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 12 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 62239)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 62241)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 62236)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 12!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52166)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52167)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52174)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 13 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52175)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52168)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52170)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 13!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52208)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52210)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52214)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 14 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52215)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52217)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52209)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 14!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58036)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58037)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58046)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 15 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58047)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58042)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58043)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 15!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58075)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58077)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58078)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 16 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58079)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58081)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58076)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 16!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54064)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54070)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54076)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 17 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54077)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54069)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54075)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 17!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54112)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54114)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54116)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 18 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54117)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54113)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54115)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 18!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54149)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54156)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54158)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 19 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 50586)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54151)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54157)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 19!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61159)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61162)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61168)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 20 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61172)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61161)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61165)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 20!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58306)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58308)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58310)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 21 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58314)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58307)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58309)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 21!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58348)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58354)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58361)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 22 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58363)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58356)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58360)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 22!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58393)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58396)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58399)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 23 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 58401)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 58402)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58394)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 23!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61832)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61833)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61853)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 24 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61854)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61839)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61849)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 24!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61877)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 61882)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61883)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 25 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 61885)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51357)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 61878)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 25!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51382)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51383)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51388)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 26 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51389)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51385)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51387)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 26!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51466)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51471)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51473)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 27 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51475)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51479)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51468)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 27!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 50426)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 50428)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 50433)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 28 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 50435)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 50430)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 50431)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 28!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 50475)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 50477)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 50478)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 29 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 50481)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 50483)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 50476)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 29!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51882)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51883)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51886)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 30 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51888)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51884)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51885)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# ...
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 58792)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 42 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51746)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51748)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51745)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 42!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51774)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51781)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51773)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 43 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51785)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51775)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51782)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 43!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51807)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51810)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51818)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 44 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 51819)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 51809)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 51811)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 44!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 65216)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 65220)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 65222)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 45 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 65223)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 65227)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 65221)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 45!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 65248)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 65249)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 65255)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 46 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 65258)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 65250)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 65252)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 46!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 63120)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 63125)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 63127)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 47 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 63128)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 63132)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 63122)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 47!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 63172)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 63176)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 63179)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 48 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 63182)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 63177)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 63178)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 48!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 60091)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 60098)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 60102)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 49 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 60103)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 60094)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 60101)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 49!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 60137)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 60139)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 60147)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Iniciando rodada 50 de aprendizado federado
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 60150)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 60138)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 60146)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 1] Modelo intermediário atualizado na rodada 50!
# [Servidor Hospital 1] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 1] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando modelo global da nuvem...
# [Servidor Hospital 1] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 1] Enviando modelo global aos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52322)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 1...
# [Servidor Hospital 1] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52323)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 2...
# [Servidor Hospital 1] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52324)!
# [Servidor Hospital 1] Enviando modelo global para o cliente 3...
# [Servidor Hospital 1] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 1] Todas as rodadas de treinamento federado foram concluídas!
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 52332)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 52333)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 52334)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Enviando f1 dos clientes para a nuvem...
# [Servidor Hospital 1] Parâmetros enviados para a nuvem com sucesso!
# [Servidor Hospital 1] Aguardando conexão dos clientes...
# [Servidor Hospital 1] Cliente 1 conectado: ('127.0.0.1', 54273)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 1] Cliente 2 conectado: ('127.0.0.1', 54274)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 1] Cliente 3 conectado: ('127.0.0.1', 54275)!
# [Servidor Hospital 1] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 1] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...
# [Servidor Hospital 1] Parâmetros enviados para a nuvem com sucesso!
