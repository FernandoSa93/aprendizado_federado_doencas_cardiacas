# %%
import socket
import os
import json
import time
import numpy as np
from sklearn.neural_network import MLPClassifier

# Constantes de configuração
CLIENT_HOST = 'localhost'
CLIENT_PORT_SEND = 5102  # Porta para enviar modelo global para clientes
CLIENT_PORT_RECV = 5103  # Porta para receber modelo local dos clientes

MASTER_HOST = 'localhost'
MASTER_PORT_SEND = 6000  # Envia modelo intermediário para a nuvem
MASTER_PORT_RECV = 6001  # Recebe modelo global da nuvem

SERVER_ID = 2   # Identificador do servidor (para simulação com múltiplos servidores)
NUM_CLIENTS = 3 # Quantidade de clientes esperados

def receive_client_parameters(conn):
    data = b""
    while True:
        packet = conn.recv(CLIENT_PORT_RECV)
        if not packet:
            break
        data += packet

    decoded = json.loads(data.decode('utf-8'))
    coef = [np.array(layer) for layer in decoded['coef']]
    intercept = [np.array(b) for b in decoded['intercept']]
    data_size = int(decoded['data_size'])

    return coef, intercept, data_size

global_coef = None
global_intercept = None

print(f"\n[Servidor Hospital {SERVER_ID}] Inicializado...")

print(f"\n[Servidor Hospital {SERVER_ID}] Aguardando modelo global inicial da nuvem...")

with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_RECV))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)

    try:
        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
        global_params = decoded.get("params", {})
        NUM_ROUNDS = np.array(decoded['num_rounds']) 

        # Cria o modelo com os mesmos hiperparâmetros do master
        global_model = MLPClassifier(**global_params)

        # Atribui os pesos recebidos
        global_model.coefs_ = [np.array(layer) for layer in decoded['coef']]
        global_model.intercepts_ = [np.array(b) for b in decoded['intercept']]
        
        print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial recebido com sucesso!")
    except Exception as e:
        print(f"[Servidor Hospital {SERVER_ID}] Erro ao receber modelo inicial: {e}")
    finally:
        s.close()

print(f"\n[Servidor Hospital {SERVER_ID}] Conectando aos clientes...")    
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
    s.listen(NUM_CLIENTS)

    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Conectado ao cliente {i+1}!")
            print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global inicial para o cliente {i+1}...")
            model_data = {
                "coef": [layer.tolist() for layer in global_coef],
                "intercept": [b.tolist() for b in global_intercept],
                "num_rounds" : int(NUM_ROUNDS),
                "params": {
                    "hidden_layer_sizes": global_model.hidden_layer_sizes,
                    "activation": global_model.activation,
                    "solver": global_model.solver,
                    "learning_rate_init": global_model.learning_rate_init,
                    "alpha": global_model.alpha,
                    "max_iter": global_model.max_iter,
                    "warm_start": global_model.warm_start,
                    "n_iter_no_change": global_model.n_iter_no_change,
                    "random_state": global_model.random_state
                }
            }
            data = json.dumps(model_data).encode('utf-8') 
            conn.sendall(data)
            print(f"[Servidor Hospital {SERVER_ID}] Modelo global inicial enviado para o cliente {i+1} com sucesso!")

for round_num in range(1, NUM_ROUNDS + 1):
    print(f"\n[Servidor Hospital {SERVER_ID}] Iniciando rodada {round_num} de aprendizado federado")

    client_weights = []
    client_sizes = []

    # Receber modelo local dos clientes
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
        s.listen(NUM_CLIENTS)
        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                client_coef, client_intercept, data_size = receive_client_parameters(conn)

                if not (isinstance(client_coef, list) and all(isinstance(layer, np.ndarray) for layer in client_coef) and
                    isinstance(client_intercept, list) and all(isinstance(b, np.ndarray) for b in client_intercept) and
                    isinstance(data_size, int)):
                    raise ValueError("Dados recebidos do cliente estão em formato incorreto.")

                client_weights.append((client_coef, client_intercept))
                client_sizes.append(data_size)

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

    # Inicializa os acumuladores se for a primeira rodada
    if global_coef is None:
        # Inicializa uma lista de arrays, um para cada camada
        global_coef = [np.zeros_like(layer) for layer in hospital_weights[0][0]]
        global_intercept = [np.zeros_like(bias) for bias in hospital_weights[0][1]]
    else:
        # Zera os valores das camadas
        for i in range(len(global_coef)):
            global_coef[i].fill(0)
            global_intercept[i].fill(0)

    total_data_size = sum(client_sizes)
    if total_data_size == 0:
        raise ValueError("Tamanho total dos dados dos clientes é zero.")

    # Realização do FedAvg(Agregação por média)
    # Coef e Intercept são os parâmetros utilizados pelo modelo
    # - Coef(Coeficiente): Representa os pesos atribuídos a cada atributo (feature) do modelo. É um vetor ou matriz (dependendo da tarefa) que determina quanto cada variável influencia a predição.
    # - Intercept(Intercepto): É o termo de bias, o valor que o modelo usa quando todas as entradas são zero. Serve para ajustar o ponto de corte (threshold) da função de decisão.
    print(f"[Servidor Hospital {SERVER_ID}] Realizando FedAvg do modelo intermediário...")
    for i in range(NUM_CLIENTS):
        weight = client_sizes[i] / total_data_size
        local_coef, local_intercept = client_weights[i]

        for j in range(len(global_coef)):
            global_coef[j] += local_coef[j] * weight
            global_intercept[j] += local_intercept[j] * weight

    # Atualizar modelo global
    global_model.coefs_ = global_coef
    global_model.intercepts_ = global_intercept
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário atualizado na rodada {round_num}!")

    # Enviar modelo intermediário para a nuvem
    hospital_model = {
        "coef": [layer.tolist() for layer in global_coef],
        "intercept": [b.tolist() for b in global_intercept],
        "data_size": total_data_size
    }

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo intermediário para a nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_SEND))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)
        s.sendall(json.dumps(hospital_model).encode('utf-8'))
    print(f"[Servidor Hospital {SERVER_ID}] Modelo intermediário enviado para a nuvem com sucesso!")

    # Receber modelo global da nuvem
    print(f"[Servidor Hospital {SERVER_ID}] Aguardando modelo global da nuvem...")
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        while True:
            try:
                s.connect((MASTER_HOST, MASTER_PORT_RECV))
                break
            except (ConnectionRefusedError, socket.timeout):
                time.sleep(1)

        received_data = b""
        while True:
            chunk = s.recv(MASTER_PORT_RECV)
            if not chunk:
                break
            received_data += chunk

        decoded = json.loads(received_data.decode('utf-8'))
        global_coef = [np.array(layer) for layer in decoded['coef']]
        global_intercept = [np.array(b) for b in decoded['intercept']]
    print(f"[Servidor Hospital {SERVER_ID}] Modelo global recebido da nuvem com sucesso!")

    print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global aos clientes...")    
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
        s.bind((CLIENT_HOST, CLIENT_PORT_SEND))
        s.listen(NUM_CLIENTS)

        for i in range(NUM_CLIENTS):
            conn, addr = s.accept()
            with conn:
                print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")
                model_data = {
                    "coef": [layer.tolist() for layer in global_coef],
                    "intercept": [b.tolist() for b in global_intercept],
                }
                data = json.dumps(model_data).encode('utf-8') 
                print(f"[Servidor Hospital {SERVER_ID}] Enviando modelo global para o cliente {i+1}...")
                conn.sendall(data)
                print(f"[Servidor Hospital {SERVER_ID}] Modelo global enviado para o cliente {i+1} com sucesso!")

print(f"\n[Servidor Hospital {SERVER_ID}] Todas as rodadas de treinamento federado foram concluídas!")

# Receber f1 dos clientes
f1_all_clients = {}  # dicionário para armazenar F1 por cliente
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                received = json.loads(received_data.decode('utf-8'))
                client_id = received["id"]
                f1_all_clients[client_id] = received["f1"]

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Enviar f1 dos clientes para o master
print(f"[Servidor Hospital {SERVER_ID}] Enviando f1 dos clientes para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    data_to_send = {
        "id": SERVER_ID,
        "f1": f1_all_clients
    }
    s.sendall(json.dumps(data_to_send).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")

aggregated_metrics = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# Receber métricas de desempenho do modelo local dos clientes
print(f"[Servidor Hospital {SERVER_ID}] Aguardando conexão dos clientes...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((CLIENT_HOST, CLIENT_PORT_RECV))
    s.listen(NUM_CLIENTS)
    
    for i in range(NUM_CLIENTS):
        conn, addr = s.accept()
        with conn:
            print(f"[Servidor Hospital {SERVER_ID}] Cliente {i+1} conectado: {addr}!")

            # Receber os dados em partes até o fim da conexão
            received_data = b""
            while True:
                chunk = conn.recv(CLIENT_PORT_RECV)
                if not chunk:
                    break
                received_data += chunk

            try:
                metrics = json.loads(received_data.decode('utf-8'))
                aggregated_metrics['accuracy'].append(metrics['accuracy'])
                aggregated_metrics['precision'].append(metrics['precision'])
                aggregated_metrics['recall'].append(metrics['recall'])
                aggregated_metrics['f1_score'].append(metrics['f1_score'])

                print(f"[Servidor Hospital {SERVER_ID}] Parâmetros recebidos do cliente {i+1} com sucesso!")

            except json.JSONDecodeError as e:
                print(f"[Servidor Hospital {SERVER_ID}] Erro ao decodificar JSON do cliente {i+1}: {e}")
                print("Conteúdo bruto recebido:", received_data)

# Média intermediária
avg_metrics = {k: np.mean(v) for k, v in aggregated_metrics.items()}

# Enviar ao mestre
print(f"[Servidor Hospital {SERVER_ID}] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...")
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    while True:
        try:
            s.connect((MASTER_HOST, MASTER_PORT_SEND))
            break
        except (ConnectionRefusedError, socket.timeout):
            time.sleep(1)
    s.sendall(json.dumps(avg_metrics).encode('utf-8'))
print(f"[Servidor Hospital {SERVER_ID}] Parâmetros enviados para a nuvem com sucesso!")
# Out:
# [Servidor Hospital 2] Inicializado...
#
# [Servidor Hospital 2] Aguardando modelo global inicial da nuvem...
# [Servidor Hospital 2] Modelo global inicial recebido com sucesso!
#
# [Servidor Hospital 2] Conectando aos clientes...
# [Servidor Hospital 2] Conectado ao cliente 1!
# [Servidor Hospital 2] Enviando modelo global inicial para o cliente 1...
# [Servidor Hospital 2] Modelo global inicial enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Conectado ao cliente 2!
# [Servidor Hospital 2] Enviando modelo global inicial para o cliente 2...
# [Servidor Hospital 2] Modelo global inicial enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Conectado ao cliente 3!
# [Servidor Hospital 2] Enviando modelo global inicial para o cliente 3...
# [Servidor Hospital 2] Modelo global inicial enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 1 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 65288)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 57830)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 62095)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 1!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54813)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54845)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54818)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 2 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54850)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54848)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54849)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 2!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 64224)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 64226)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 64223)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 3 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 64227)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 64229)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 64225)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 3!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 64268)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 64270)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 64272)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 4 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 64273)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 64269)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 64271)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 4!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58317)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58319)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58321)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 5 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58322)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58318)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58320)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 5!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58350)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58352)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58354)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 6 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58355)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58351)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58353)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 6!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 57687)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 57688)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61337)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 7 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61338)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 57689)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 57690)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 7!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61382)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61384)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61385)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 8 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61386)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61388)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61383)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 8!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 53544)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 53545)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 53548)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 9 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 53549)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 53546)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 53547)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 9!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 53577)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 53579)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 53580)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 10 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 53581)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 53583)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 53578)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 10!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 62179)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 62180)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 62183)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 11 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 62184)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 62182)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 62181)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 11!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 62212)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 62225)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 62226)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 12 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 62227)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 62230)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 62213)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 12!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52159)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52160)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52163)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 13 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52164)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52161)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52162)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 13!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52200)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52201)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52203)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 14 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52204)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52206)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52202)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 14!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52233)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52234)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52237)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 15 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58038)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52235)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52236)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 15!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58064)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58065)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58066)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 16 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58067)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58069)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58071)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 16!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54542)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54541)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54543)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 17 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54065)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54067)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54071)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 17!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54102)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54099)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54103)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 18 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54104)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54106)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54108)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 18!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54147)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54146)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54148)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 19 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54152)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54154)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54150)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 19!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61157)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61160)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61156)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 20 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61163)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61166)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61158)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 20!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61189)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61190)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61191)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 21 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61193)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58304)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61192)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 21!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58346)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58343)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58344)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 22 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58350)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58357)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58349)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 22!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58389)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58390)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58395)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 23 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 58397)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 58391)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 58392)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 23!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61829)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61830)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61838)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 24 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61846)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61831)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61837)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 24!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61875)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61879)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61880)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 25 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 61876)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 61886)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 61881)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 25!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51380)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51381)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51391)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 26 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51392)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51384)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51386)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 26!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51467)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51470)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51472)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 27 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51481)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51469)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51474)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 27!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 50429)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 50434)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 50452)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 28 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 50456)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 50432)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 50451)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 28!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 50480)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 50479)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 50543)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 29 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 50547)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 50488)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 50499)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 29!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51887)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51891)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51893)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 30 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51897)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51899)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51890)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# ...
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51751)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 42 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51752)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51754)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51744)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 42!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51776)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51777)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51780)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 43 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51783)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51778)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51779)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 43!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51806)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51812)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51813)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 44 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 51814)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 51816)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 51808)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 44!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 65206)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 65215)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 65218)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 45 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 65224)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 65217)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 65219)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 45!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 65247)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 65253)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 65254)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 46 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 65256)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 65260)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 65251)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 46!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 63119)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 63121)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 63126)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 47 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 63130)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 63123)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 63124)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 47!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 63173)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 63180)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 63181)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 48 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 63183)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 63184)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 63174)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 48!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 60093)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 60092)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 60097)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 49 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 60099)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 60095)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 60096)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 49!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 60135)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 60140)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 60141)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Iniciando rodada 50 de aprendizado federado
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 60142)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 60144)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 60136)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Realizando FedAvg do modelo intermediário...
# [Servidor Hospital 2] Modelo intermediário atualizado na rodada 50!
# [Servidor Hospital 2] Enviando modelo intermediário para a nuvem...
# [Servidor Hospital 2] Modelo intermediário enviado para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando modelo global da nuvem...
# [Servidor Hospital 2] Modelo global recebido da nuvem com sucesso!
# [Servidor Hospital 2] Enviando modelo global aos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52319)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 1...
# [Servidor Hospital 2] Modelo global enviado para o cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52320)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 2...
# [Servidor Hospital 2] Modelo global enviado para o cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52321)!
# [Servidor Hospital 2] Enviando modelo global para o cliente 3...
# [Servidor Hospital 2] Modelo global enviado para o cliente 3 com sucesso!
#
# [Servidor Hospital 2] Todas as rodadas de treinamento federado foram concluídas!
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 52326)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 52327)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 52330)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Enviando f1 dos clientes para a nuvem...
# [Servidor Hospital 2] Parâmetros enviados para a nuvem com sucesso!
# [Servidor Hospital 2] Aguardando conexão dos clientes...
# [Servidor Hospital 2] Cliente 1 conectado: ('127.0.0.1', 54269)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 1 com sucesso!
# [Servidor Hospital 2] Cliente 2 conectado: ('127.0.0.1', 54270)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 2 com sucesso!
# [Servidor Hospital 2] Cliente 3 conectado: ('127.0.0.1', 54271)!
# [Servidor Hospital 2] Parâmetros recebidos do cliente 3 com sucesso!
# [Servidor Hospital 2] Enviando parâmetros de desempenho do modelo intermediário para a nuvem...
# [Servidor Hospital 2] Parâmetros enviados para a nuvem com sucesso!
